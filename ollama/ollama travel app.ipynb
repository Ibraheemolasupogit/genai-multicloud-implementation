# %%
import requests
import json
from datetime import datetime, timedelta

class TripPlanner:
    def __init__(self, ollama_base_url="http://localhost:11434"):
        self.ollama_base_url = ollama_base_url
        
    def generate_prompt(self, destination, num_days):
        return f"""Create a detailed {num_days}-day trip itinerary for {destination}. 
        Please provide a day-by-day breakdown including:
        - Morning activities and attractions
        - Afternoon activities
        - Evening activities and dinner suggestions
        - Must-visit locations
        - Local food recommendations
        - Transportation tips
        
        Please write it in a natural, conversational style that's easy to read.
        Make it detailed but friendly, as if you're suggesting this itinerary to a friend."""

    def get_itinerary(self, destination, num_days):
        prompt = self.generate_prompt(destination, num_days)
        
        try:
            # Test connection to Ollama first
            try:
                requests.get(f"{self.ollama_base_url}/api/tags")
            except requests.exceptions.ConnectionError:
                return "Error: Cannot connect to Ollama. Please ensure Ollama is running (ollama run mistral)"

            # Use the correct API endpoint for chat completion
            response = requests.post(
                f"{self.ollama_base_url}/api/chat",
                json={
                    "model": "llama3.2:1b",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ],
                    "stream": False
                }
            )
            
            if response.status_code == 200:
                response_text = response.json().get('message', {}).get('content', '')
                return self.format_output(response_text, num_days, destination)
            else:
                return (f"Error: Unable to generate itinerary. Status code: {response.status_code}\n"
                       f"Make sure you have pulled the mistral model using 'ollama pull mistral'")
                
        except requests.exceptions.RequestException as e:
            return f"Error connecting to Ollama: {str(e)}\nPlease ensure Ollama is running on {self.ollama_base_url}"

    def format_output(self, text, num_days, destination):
        """Format the response in a human-readable way"""
        # Add a decorative header
        formatted_output = [
            "╔══════════════════════════════════════════════════╗",
            f"             Your {num_days}-Day Trip to {destination.title()}",
            "╚══════════════════════════════════════════════════╝\n"
        ]

        # Split the text into days if it contains day markers
        days = []
        current_day = []
        
        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue
                
            # Check for day markers in various formats
            day_starts = [f"Day {i}:" for i in range(1, num_days + 1)] + [f"Day {i}" for i in range(1, num_days + 1)]
            
            if any(line.startswith(day) for day in day_starts):
                if current_day:
                    days.append('\n'.join(current_day))
                current_day = [line]
            else:
                current_day.append(line)
                
        if current_day:
            days.append('\n'.join(current_day))

        # If no clear day structure, split text roughly into days
        if len(days) != num_days:
            text_chunks = text.split('\n\n')
            days = []
            current_chunk = []
            chunk_size = len(text_chunks) // num_days
            
            for i, chunk in enumerate(text_chunks):
                current_chunk.append(chunk)
                if (i + 1) % chunk_size == 0 and len(days) < num_days:
                    days.append('\n'.join(current_chunk))
                    current_chunk = []

        # Format each day
        for i, day_content in enumerate(days, 1):
            formatted_output.extend([
                f"\n{'═' * 50}",
                f"🌅 Day {i}",
                f"{'═' * 50}\n",
                day_content.strip(),
                "\n"
            ])

        # Add footer with travel tips
        formatted_output.extend([
            "╔══════════════════════════════════════════════════╗",
            "                  Travel Tips 🎯",
            "╚══════════════════════════════════════════════════╝",
            "• Remember to check opening hours for attractions",
            "• Keep local emergency numbers handy",
            "• Respect local customs and traditions",
            "• Stay hydrated and carry weather-appropriate gear",
            "• Have a fantastic trip! 🌟"
        ])

        return '\n'.join(formatted_output)

def main():
    print("\n🌎 Welcome to Your Personal Trip Planner! 🌎\n")
    
    destination = input("Where would you like to go? ")
    while True:
        try:
            num_days = int(input("How many days will you be traveling? "))
            if num_days > 0:
                break
            print("Please enter a positive number of days.")
        except ValueError:
            print("Please enter a valid number.")
    
    print("\n✨ Creating your personalized travel itinerary... ✨")
    planner = TripPlanner()
    print("\n" + planner.get_itinerary(destination, num_days))

if __name__ == "__main__":
    main()
# Out:
# 🌎 Welcome to Your Personal Trip Planner! 🌎
# Where would you like to go?  Pataya
# How many days will you be traveling?  3
# ✨ Creating your personalized travel itinerary... ✨
#
# ╔══════════════════════════════════════════════════╗
#              Your 3-Day Trip to Pataya
# ╚══════════════════════════════════════════════════╝
#
#
# ══════════════════════════════════════════════════
# 🌅 Day 1
# ══════════════════════════════════════════════════
#
# Pataya, the vibrant city in northeastern Thailand known for its stunning beaches, rich culture, and delicious food. I've put together a 3-day trip itinerary just for you, packed with exciting activities, must-visit locations, and mouth-watering recommendations.
# **Day 1: Beach Relaxation and Water Activities**
# Morning:
# * Start your day with a leisurely breakfast at one of Pataya's many cafes or bakeries. Try the famous Khanom Buang (Thai-style crepes) at Khao Yai Coffee.
# * Head to Patong Beach, one of the most popular beaches in Thailand. Soak up the sun, take a dip in the ocean, and enjoy the lively atmosphere.
# Afternoon:
# * Rent a kayak or paddleboard and explore the nearby mangrove forests. You might spot dolphins, monkeys, or even sea turtles!
# * Visit the Patong Night Market (open from 4 pm to midnight) for some shopping and street food. Be sure to try some fresh coconuts and local snacks.
# Evening:
# * Head to the Khao Yai River for a relaxing evening stroll along the riverbank. Watch the sunset over the water, and enjoy the tranquil atmosphere.
# * For dinner, head to Som Tam Jay, a popular restaurant serving delicious and spicy Thai dishes. Try their famous Tom Yum soup or Pad Thai.
# Must-visit locations:
# * Patong Beach
# * Patong Night Market
# * Khao Yai River
# Local food recommendations:
# * Khanom Buang (Thai-style crepes)
# * Fresh coconuts at the Patong Night Market
# * Som Tam Jay (try their Tom Yum soup!)
#
#
#
# ══════════════════════════════════════════════════
# 🌅 Day 2
# ══════════════════════════════════════════════════
#
# **Day 2: Cultural Experiences and Shopping**
# Morning:
# * Visit the Wat Phra Kaew Museum, which houses some of Thailand's most treasured religious artifacts. Be sure to check out the Emerald Buddha!
# * Take a short walk to the nearby Wat Pho Temple, home to over 200 Buddha images.
# Afternoon:
# * Explore the Patong Art Market (open from 10 am to 6 pm), where you can find unique souvenirs and local handicrafts.
# * Visit the Emporium Mall for some shopping and browsing. You'll find everything from high-end fashion to affordable fashion brands.
# Evening:
# * Enjoy dinner at La Mio, a stylish Italian restaurant with stunning views of the city skyline.
# * After dinner, head to the Patong Beach Bar & Grill for live music and cocktails.
# Must-visit locations:
# * Wat Phra Kaew Museum
# * Wat Pho Temple
# * Emporium Mall
# Local food recommendations:
# * La Mio (Italian cuisine)
# * Patong Beach Bar & Grill (cocktails and seafood)
# **Day 3: Cultural Immersion and Waterfalls**
#
#
#
# ══════════════════════════════════════════════════
# 🌅 Day 3
# ══════════════════════════════════════════════════
#
# Morning:
# * Visit the Khao Yai National Park, one of Thailand's oldest national parks. Take a short hike to the scenic waterfalls.
# * Stop by the Wat Phra Mahathat temple for some stunning views of the surrounding area.
# Afternoon:
# * Return to Pataya and visit the Central Festival Shopping Mall for some shopping and relaxation. You can also take a stroll along the canal.
# Evening:
# * Enjoy dinner at The Beach, a popular restaurant serving fresh seafood.
# * End your trip with a sunset cruise on the Phang Nga Bay (book in advance).
# Must-visit locations:
# * Khao Yai National Park
# * Wat Phra Mahathat temple
# Local food recommendations:
# * The Beach (fresh seafood)
# * Central Festival Shopping Mall
# Transportation tips:
# * Rent a motorbike or scooter to get around Pataya, but be sure to follow traffic rules.
# * Use taxis or ride-hailing apps like Grab for convenient transportation.
# * Consider purchasing a local SIM card or renting a portable Wi-Fi hotspot for easy navigation.
#
#
# ╔══════════════════════════════════════════════════╗
#                   Travel Tips 🎯
# ╚══════════════════════════════════════════════════╝
# • Remember to check opening hours for attractions
# • Keep local emergency numbers handy
# • Respect local customs and traditions
# • Stay hydrated and carry weather-appropriate gear
# • Have a fantastic trip! 🌟

# %%
import gradio as gr
import requests
import json

class TripPlanner:
    def __init__(self, ollama_base_url="http://localhost:11434"):
        self.ollama_base_url = ollama_base_url
        
    def generate_prompt(self, destination, num_days):
        return f"""Create a detailed {num_days}-day trip itinerary for {destination}. \
        Please provide a day-by-day breakdown including:\
        - Morning activities and attractions\
        - Afternoon activities\
        - Evening activities and dinner suggestions\
        - Must-visit locations\
        - Local food recommendations\
        - Transportation tips\
        \n        Please write it in a natural, conversational style that's easy to read.\
        Make it detailed but friendly, as if you're suggesting this itinerary to a friend."""

    def get_itinerary(self, destination, num_days):
        prompt = self.generate_prompt(destination, num_days)
        
        try:
            # Test connection to Ollama first
            try:
                requests.get(f"{self.ollama_base_url}/api/tags")
            except requests.exceptions.ConnectionError:
                return "Error: Cannot connect to Ollama. Please ensure Ollama is running (ollama run mistral)"

            # Use the correct API endpoint for chat completion
            response = requests.post(
                f"{self.ollama_base_url}/api/chat",
                json={
                    "model": "llama3.2:1b",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ],
                    "stream": False
                }
            )
            
            if response.status_code == 200:
                response_text = response.json().get('message', {}).get('content', '')
                return self.format_output(response_text, num_days, destination)
            else:
                return (f"Error: Unable to generate itinerary. Status code: {response.status_code}\n"
                       f"Make sure you have pulled the mistral model using 'ollama pull mistral'")
                
        except requests.exceptions.RequestException as e:
            return f"Error connecting to Ollama: {str(e)}\nPlease ensure Ollama is running on {self.ollama_base_url}"

    def format_output(self, text, num_days, destination):
        formatted_output = [
            f"Your {num_days}-Day Trip to {destination.title()}\n",
            "=" * 50
        ]

        days = []
        current_day = []

        for line in text.split('\n'):
            line = line.strip()
            if not line:
                continue

            day_starts = [f"Day {i}:" for i in range(1, num_days + 1)] + [f"Day {i}" for i in range(1, num_days + 1)]

            if any(line.startswith(day) for day in day_starts):
                if current_day:
                    days.append('\n'.join(current_day))
                current_day = [line]
            else:
                current_day.append(line)

        if current_day:
            days.append('\n'.join(current_day))

        if len(days) != num_days:
            text_chunks = text.split('\n\n')
            days = []
            current_chunk = []
            chunk_size = len(text_chunks) // num_days

            for i, chunk in enumerate(text_chunks):
                current_chunk.append(chunk)
                if (i + 1) % chunk_size == 0 and len(days) < num_days:
                    days.append('\n'.join(current_chunk))
                    current_chunk = []

        for i, day_content in enumerate(days, 1):
            formatted_output.extend([
                f"\nDay {i}\n",
                "-" * 50,
                day_content.strip(),
                "\n"
            ])

        formatted_output.extend([
            "\nTravel Tips:\n",
            "• Remember to check opening hours for attractions",
            "• Keep local emergency numbers handy",
            "• Respect local customs and traditions",
            "• Stay hydrated and carry weather-appropriate gear",
            "• Have a fantastic trip!"
        ])

        return '\n'.join(formatted_output)


def interact_with_trip_planner(destination, num_days):
    try:
        num_days = int(num_days)
        if num_days <= 0:
            return "Please enter a positive number of days."
    except ValueError:
        return "Invalid number of days. Please enter a valid number."

    planner = TripPlanner()
    return planner.get_itinerary(destination, num_days)


def main():
    iface = gr.Interface(
        fn=interact_with_trip_planner,
        inputs=[
            gr.Textbox(label="Destination", placeholder="Enter your travel destination"),
            gr.Textbox(label="Number of Days", placeholder="Enter number of days")
        ],
        outputs=gr.Textbox(label="Travel Itinerary"),
        title="Trip Planner",
        description="Generate a detailed trip itinerary for your destination."
    )

    iface.launch()


if __name__ == "__main__":
    main()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
